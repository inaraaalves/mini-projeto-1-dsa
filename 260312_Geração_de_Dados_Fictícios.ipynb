# %% [markdown]
# <a href="https://colab.research.google.com/github/inaraaalves/mini-projeto-1-dsa/blob/main/260312_Gera%C3%A7%C3%A3o_de_Dados_Fict%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de Bibliotecas

# %%
# Importação da biblioteca random para geração de números aleatórios
import random

# Importação das classes datetime e timedelta para manipulação de datas e intervalos de tempo
from datetime import datetime, timedelta

# Salva csv no drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Função Para Geração de Dados Fictícios**

# %%
# Definição da função para gerar dados fictícios de vendas
def gera_dados_ficticios(num_registros = 1500):

    """
    Gera um DataFrame do Pandas com dados de vendas fictícios.
    """

    # Mensagem inicial indicando a quantidade de registros a serem gerados
    print(f"\nIniciando a geração de {num_registros} registros de vendas...")

    # Dicionário com produtos, categorias, preços
    produtos = {
        'Perfume Aurora': {'categoria': 'Perfumaria', 'preco': 150.00},
        'Perfume Elegance': {'categoria': 'Perfumaria', 'preco': 350.00},
        'Perfume Bloom': {'categoria': 'Perfumaria', 'preco': 100.00},
        'Condicionador Luxo': {'categoria': 'Banho', 'preco': 60.00},
        'Esfoliante Premium': {'categoria': 'Banho', 'preco': 50.00},
        'Base Lux': {'categoria': 'Maquiagem', 'preco': 80.00},
        'Gloss Crystal': {'categoria': 'Maquiagem', 'preco': 50.00},
        'Batom Matte': {'categoria': 'Maquiagem', 'preco': 85.00}
    }


    # Cria uma lista apenas com os nomes dos produtos
    lista_produtos = list(produtos.keys())

    # Dicionário com cidades e seus respectivos estados
    cidades_estados = {
        'Manaus': 'AM', 'Belém': 'PA', 'São Luís': 'MA',
        'São Paulo': 'SP', 'Rio de Janeiro': 'RJ', 'Belo Horizonte': 'MG',
        'Porto Alegre': 'RS', 'Salvador': 'BA', 'Curitiba': 'PR', 'Fortaleza': 'CE'
    }

    # Cria uma lista apenas com os nomes das cidades
    lista_cidades = list(cidades_estados.keys())

    # Lista que armazenará os registros de vendas
    dados_vendas = []

    # Define a data inicial dos pedidos
    data_inicial = datetime(2025, 1, 1)



    # Loop para gerar os registros de vendas
    for i in range(num_registros):

        # Seleciona aleatoriamente um produto
        produto_nome = random.choice(lista_produtos)

        # Seleciona aleatoriamente uma cidade
        cidade = random.choice(lista_cidades)

        # Gera uma quantidade de produtos vendida entre 1 e 10
        quantidade = np.random.randint(1, 10)

        # Calcula a data do pedido a partir da data inicial
        data_pedido = data_inicial + timedelta(days = int(i/5), hours = random.randint(0, 23))

        # Se o produto for Condicionador Luxo ou Esfoliante Premium, aplica desconto aleatório de até 10%
        if produto_nome in ['Condicionador Luxo', 'Esfoliante Premium']:
            preco_unitario = produtos[produto_nome]['preco'] * np.random.uniform(0.9, 1.0)
        else:
            preco_unitario = produtos[produto_nome]['preco']

        # Adiciona um registro de venda à lista
        dados_vendas.append({
            'ID_Pedido': 1000 + i,
            'Data_Pedido': data_pedido,
            'Nome_Produto': produto_nome,
            'Categoria': produtos[produto_nome]['categoria'],
            'Preco_Unitario': round(preco_unitario, 2),
            'Quantidade': quantidade,
            'ID_Cliente': np.random.randint(100, 250),
            'Cidade': cidade,
            'Estado': cidades_estados[cidade]
        })

    # Mensagem final indicando que a geração terminou
    print("Geração de dados concluída.\n")

    # Retorna os dados no formato de DataFrame
    return pd.DataFrame(dados_vendas)


# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# DataFrame final com os dados fictícios gerados aleatoriamente
df = gera_dados_ficticios()


# Salvar no Drive
df.to_csv('/content/drive/MyDrive/Colab Notebooks/DATA SCIENCE ACADEMY/Mini Projeto 1/petalas_dados_de_vendas.csv', index=False)
print("csv salvo no Drive!")
# Out:
# Iniciando a geração de 1500 registros de vendas...
# Geração de dados concluída.
#
# csv salvo no Drive!
